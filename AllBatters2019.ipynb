# %%
import pandas as pd
import glob

# %%
listacsv = glob.glob('2019BatterData/*detail.csv')

# %%
df = pd.concat([pd.read_csv(f) for f in listacsv], ignore_index = True)

# %%
df[(df['player_name'] == 'Mookie Betts') & (df['game_date'] == '2019-03-28')][::-1]
# Out:
#        pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 100106         SI  2019-03-28           89.0         2.5416         5.8695
# 100105         CH  2019-03-28           80.6         2.8936         5.6635
# 100104         CH  2019-03-28           81.2         2.9035         5.6385
# 100103         FC  2019-03-28           84.8         2.7215         5.7228
# 100102         SI  2019-03-28           89.1         2.5425         5.7929
# 100069         FC  2019-03-28           85.3         2.6613         5.6124
# 100068         CH  2019-03-28           81.3         3.0434         5.4697
# 100067         CH  2019-03-28           80.7         2.9287         5.4794
# 100040         CH  2019-03-28           79.5         3.0826         5.6731
# 100039         SI  2019-03-28           87.6         2.6330         5.7079
# 100038         FC  2019-03-28           84.2         2.7944         5.6004
# ...

# %%
df.to_csv('AllBatters2019.csv', index=False, sep=',')
